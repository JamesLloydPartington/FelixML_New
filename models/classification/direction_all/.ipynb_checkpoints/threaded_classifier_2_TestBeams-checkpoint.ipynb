# %%
#import modules

import numpy as np
import os
import matplotlib.pyplot as plt
import pickle

from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing import image_dataset_from_directory
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.regularizers import l2
from keras.utils import to_categorical
from keras.utils import multi_gpu_model
from keras.utils import Sequence
from keras.models import load_model
from tensorflow.distribute import MirroredStrategy

# %%
#initialise random generator
rng = np.random.default_rng()

# %%
#Define FelixDataflow classes and functions.

class FelixSequence(Sequence):
    def __init__(self, x_set, y_set, batch_size, file_type, use_index):
        """Here self.x is a list of paths to file_type files. self.y is a
        corresponding list of labels."""
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size
        self.file_type = file_type
        self.use_index = use_index

    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]
        return arrs_from_paths(batch_x, self.file_type, self.use_index), to_categorical(np.array(batch_y),10)

def gen_paths_labels(base_path):
    """A generator to yield (data-paths, corresponding labels) tuples for each
    segment of data (typically training, validation, and testing)."""
    for segment in sorted(os.listdir(base_path)):
        segment_path = os.path.join(base_path, segment)
        segment_paths = []
        segment_labels = []
        for label in os.listdir(segment_path):
            label_path = os.path.join(segment_path, label)
            for crystal in os.listdir(label_path):
                segment_paths.append(os.path.join(label_path, crystal))
                segment_labels.append(label)
        indexes = np.arange(len(segment_labels))
        rng.shuffle(indexes)
        yield [np.array(segment_paths)[indexes], np.array(list(map(int,segment_labels)))[indexes]]

def arrs_from_paths(paths, file_type, use_index):
    if file_type == "txt":
        return np.array([np.loadtxt(file_name) for file_name in paths])
    elif file_type == "npy":
        return np.array([np.load(file_name)[use_index,:,:] for file_name in paths])
        #return np.array([np.load(file_name) for file_name in paths])

# %%
def felix_fit_new(model, batch_size, epochs, workers, callbacks, AllPaths, file_type, train_history, val_history, patience, test_history, Monitor, use_index):
    #AllPaths = [[TrainingPaths, TrainingThickness], [], []]
    """A fit function to allow validation and test data to be supplied via a
    generator."""
    
    best_val_loss = np.inf
    best_val_acc = 0
    
    x = np.arange(0, epochs)
    
    train_seq = FelixSequence(AllPaths[0][0], AllPaths[0][1], batch_size, file_type, use_index)
    val_seq = FelixSequence(AllPaths[1][0], AllPaths[1][1], batch_size, file_type, use_index)
    test_seq = FelixSequence(AllPaths[2][0], AllPaths[2][1], batch_size, file_type, use_index)
    for epoch in range(epochs):
        print("-------------------------------------------------------------------------")
        print("Epoch", epoch+1, "/", epochs, ": ")
        print("Training: ")
        train_hist = model.fit(x = train_seq, epochs = epoch+1, workers = workers, initial_epoch = epoch, shuffle=True)
        train_history[0][epoch] = train_hist.history["loss"][0]
        train_history[1][epoch] = train_hist.history["acc"][0]
        print("Validation: ")
        val_hist = model.evaluate(x = val_seq, workers = workers, callbacks = callbacks)
        #print(val_hist)
        val_history[0][epoch] = val_hist[0]
        val_history[1][epoch] = val_hist[1]
        
        plt.plot(x, val_history[1])
        plt.show()
        
        epoch_loss = val_hist[0]
        epoch_acc = val_hist[1]
        
        
        if(Monitor == "loss"):
            if(epoch_loss < best_val_loss):
                print("The model loss improved from: ",best_val_loss, "to: ", epoch_loss)
                best_val_loss = epoch_loss
                patience_i = 0
            else:
                patience_i+=1
                print("The model did not improve, patience_i = ", patience_i)

            #val_hist[0][epoch] = avg_recon_loss
            if(patience_i > patience):
                print("Early Stopping, the model did not improve from a loss: ", best_val_loss)
                break
        
        elif(Monitor == "acc"):
            if(best_val_acc < epoch_acc):
                print("The model accuracy improved from: ",best_val_acc, "to: ", epoch_acc)
                best_val_acc = epoch_acc
                patience_i = 0
            else:
                patience_i+=1
                print("The model accuracy did not improve, patience_i = ", patience_i)

            #val_hist[0][epoch] = avg_recon_loss
            if(patience_i > patience):
                print("Early Stopping, the model did not improve from an accuracy: ", best_val_loss)
                break

    print("-------------------------------------------------------------------------")
    print("Testing: ")
    tst_hist = model.evaluate(test_seq)
    test_history[0] = tst_hist[0]
    test_history[1] = tst_hist[1]
    print("Test Results: ", tst_hist[0], tst_hist[1])
    return(tst_hist[0], tst_hist[1])

# %%
#All paths

SaveDataPath = "/home/ug-ml/Documents/GitHub_BigFiles/SaveFolder" #Base directory of place you store information of models
SaveFolderName = "/Classifer_1_V3" #Will create a folder and put in information about the outcome / inputs
ModelName = "/Model.hdf5"


#Many variables

#Model Variables


#Hyper parameters
learning_rate = 0.0005
l2_regularizer = 0.0001
loss = 'categorical_crossentropy'
optimizer = "RMSprop" #Not a variable ONLY used for a note
batch_size = 32
epochs = 20
ShuffleTrainData = True

#Call back variables
TrainingPatience = 20
CheckPointMonitor = 'val_acc'
EarlyStopMonitor = 'val_acc'

#CPU variables
CPUworkers = 16

# %%
#Early stopping and check points

EarlyStop = EarlyStopping(monitor = EarlyStopMonitor,
                          mode = 'min',
                          verbose = 1,
                          patience = TrainingPatience)

NewPath = SaveDataPath + SaveFolderName
Checkpoint = ModelCheckpoint(NewPath + ModelName, #Save path
                             monitor = CheckPointMonitor,
                             verbose = 1,
                             save_best_only = True,
                             mode = 'auto',
                             save_freq = 'epoch')

# %%
def BuildModel(input_shape):
    strategy = MirroredStrategy() #Allows multiple GPUs

    with strategy.scope():
        model = models.Sequential()
        model.add(layers.Conv2D(48 * 3, (4, 4),
                                         activation='relu',
                                         data_format='channels_first',
                                         input_shape= input_shape))
        model.add(layers.MaxPooling2D((2, 2), data_format='channels_first'))
        model.add(layers.Conv2D(48 * 3, (4, 4),
                                         data_format='channels_first',
                                         activation='relu'))
        model.add(layers.MaxPooling2D((2, 2), data_format='channels_first'))
        model.add(layers.Conv2D(48 * 3, (4, 4),
                                         data_format='channels_first',
                                         activation='relu'))
        model.add(layers.MaxPooling2D((2, 2), data_format='channels_first'))
        model.add(layers.Flatten())
        model.add(layers.Dropout(0.2))
        model.add(layers.Dense(48 * 3, activation='relu',
                               kernel_regularizer = l2(0.0001)))

        model.add(layers.Dense(10, activation='softmax',
                               kernel_regularizer = l2(0.0001)))

        model.compile(loss = 'categorical_crossentropy',
                      optimizer = optimizers.RMSprop(learning_rate = 0.0005),
                      metrics=['acc'])
        return model

# %%
def MakeThicknessList(ListPaths):
    Thickness = []
    for i in ListPaths:
        Thickness.append(int(i.split("/")[-1].split(".")[0]))
    Thickness = np.array(Thickness)
    return(Thickness)

def OpenTxt(Path):
    with open(Path) as textFile:
        lines = [line.split() for line in textFile]
    List = []
    for i in lines:
        List.append(i[0])
    return(List)

DataPath = "/home/ug-ml/felix-ML/classification/Classification15/DataPaths/"

TrainPath = OpenTxt(DataPath + "Train_0p1.txt")
ValPath = OpenTxt(DataPath + "Validation_0p1.txt")
TestPath = OpenTxt(DataPath + "Test_0p1.txt")

TrainThickness = MakeThicknessList(TrainPath)
ValThickness = MakeThicknessList(ValPath)
TestThickness = MakeThicknessList(TestPath)

AllPaths = [[TrainPath,TrainThickness],[ValPath,ValThickness],[TestPath,TestThickness]]

# %%
training_history = np.zeros(shape=(2,epochs))
validation_history = np.zeros(shape=(2,epochs))
test_history = [0,0]
#print(model.metrics_names)

NoBeamsTest = [15, 10, 6, 3, 1]
NoTests = 3

for i in NoBeamsTest:
    for j in range(0, NoTests):
        use_index = np.arange(i, dtype = np.int)
        input_shape = (i, 128, 128)
        model = BuildModel(input_shape)
        felix_fit_new(model, batch_size, epochs, CPUworkers, [EarlyStop, Checkpoint], AllPaths, "npy", training_history, validation_history, TrainingPatience, test_history, "acc", use_index)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# -------------------------------------------------------------------------
# Epoch 1 / 20 :
# Training:
# INFO:tensorflow:batch_all_reduce: 10 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 10 all-reduces with algorithm = nccl, num_packs = 1
# 3537/3537 [==============================] - 328s 93ms/step - loss: 1.6831 - acc: 0.4053
# Validation:
# 416/416 [==============================] - 38s 91ms/step - loss: 1.3357 - acc: 0.5261
# The model accuracy improved from:  0 to:  0.5260863304138184
# -------------------------------------------------------------------------
# Epoch 2 / 20 :
# Training:
# Epoch 2/2
# 3537/3537 [==============================] - 330s 93ms/step - loss: 1.3494 - acc: 0.5718
# Validation:
# 416/416 [==============================] - 38s 91ms/step - loss: 1.2324 - acc: 0.5930
# The model accuracy improved from:  0.5260863304138184 to:  0.5929935574531555
# -------------------------------------------------------------------------
# Epoch 3 / 20 :
# Training:
# Epoch 3/3
# 3537/3537 [==============================] - 329s 93ms/step - loss: 1.1814 - acc: 0.6402
# Validation:
# 416/416 [==============================] - 38s 91ms/step - loss: 1.1058 - acc: 0.6390
# The model accuracy improved from:  0.5929935574531555 to:  0.6390016674995422
# -------------------------------------------------------------------------
# Epoch 4 / 20 :
# Training:
# Epoch 4/4
# 3537/3537 [==============================] - 331s 93ms/step - loss: 1.0558 - acc: 0.6740
# Validation:
# 416/416 [==============================] - 38s 91ms/step - loss: 1.1256 - acc: 0.6640
# The model accuracy improved from:  0.6390016674995422 to:  0.6639602780342102
# -------------------------------------------------------------------------
# Epoch 5 / 20 :
# Training:
# Epoch 5/5
# 3537/3537 [==============================] - 331s 93ms/step - loss: 1.0237 - acc: 0.6970
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.0670 - acc: 0.6518
# The model accuracy did not improve, patience_i =  1
# -------------------------------------------------------------------------
# Epoch 6 / 20 :
# Training:
# Epoch 6/6
# 3537/3537 [==============================] - 330s 93ms/step - loss: 1.0130 - acc: 0.7095
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.2377 - acc: 0.6346
# The model accuracy did not improve, patience_i =  2
# -------------------------------------------------------------------------
# Epoch 7 / 20 :
# Training:
# Epoch 7/7
# 3537/3537 [==============================] - 329s 93ms/step - loss: 0.9744 - acc: 0.7160
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.0374 - acc: 0.6864
# The model accuracy improved from:  0.6639602780342102 to:  0.6863629817962646
# -------------------------------------------------------------------------
# Epoch 8 / 20 :
# Training:
# Epoch 8/8
# 3537/3537 [==============================] - 329s 93ms/step - loss: 1.0104 - acc: 0.7180
# Validation:
# 416/416 [==============================] - 38s 90ms/step - loss: 1.1075 - acc: 0.6859
# The model accuracy did not improve, patience_i =  1
# -------------------------------------------------------------------------
# Epoch 9 / 20 :
# Training:
# Epoch 9/9
# 3537/3537 [==============================] - 330s 93ms/step - loss: 0.9619 - acc: 0.7159
# Validation:
# 416/416 [==============================] - 38s 90ms/step - loss: 1.1134 - acc: 0.6596 3s - los
# The model accuracy did not improve, patience_i =  2
# -------------------------------------------------------------------------
# Epoch 10 / 20 :
# Training:
# Epoch 10/10
# 3537/3537 [==============================] - 330s 93ms/step - loss: 1.0285 - acc: 0.7175
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.1295 - acc: 0.6443
# The model accuracy did not improve, patience_i =  3
# -------------------------------------------------------------------------
# Epoch 11 / 20 :
# Training:
# Epoch 11/11
# 3537/3537 [==============================] - 329s 93ms/step - loss: 0.9799 - acc: 0.7200
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.0936 - acc: 0.6891
# The model accuracy improved from:  0.6863629817962646 to:  0.6890693306922913
# -------------------------------------------------------------------------
# Epoch 12 / 20 :
# Training:
# Epoch 12/12
# 3537/3537 [==============================] - 329s 93ms/step - loss: 1.1148 - acc: 0.7200
# Validation:
# 416/416 [==============================] - 38s 90ms/step - loss: 1.0290 - acc: 0.6936
# The model accuracy improved from:  0.6890693306922913 to:  0.693579912185669
# -------------------------------------------------------------------------
# Epoch 13 / 20 :
# Training:
# Epoch 13/13
# 3537/3537 [==============================] - 331s 93ms/step - loss: 0.9957 - acc: 0.7173
# Validation:
# 416/416 [==============================] - 38s 91ms/step - loss: 1.3971 - acc: 0.6706
# The model accuracy did not improve, patience_i =  1
# -------------------------------------------------------------------------
# Epoch 14 / 20 :
# Training:
# Epoch 14/14
# 3537/3537 [==============================] - 329s 93ms/step - loss: 1.0758 - acc: 0.7166
# Validation:
# 416/416 [==============================] - 37s 89ms/step - loss: 1.0951 - acc: 0.6993
# The model accuracy improved from:  0.693579912185669 to:  0.699293315410614
# -------------------------------------------------------------------------
# Epoch 15 / 20 :
# Training:
# Epoch 15/15
# 3537/3537 [==============================] - 329s 93ms/step - loss: 1.1324 - acc: 0.71032s -
# Validation:
# 416/416 [==============================] - 38s 90ms/step - loss: 1.1160 - acc: 0.6880
# The model accuracy did not improve, patience_i =  1
# -------------------------------------------------------------------------
# Epoch 16 / 20 :
# Training:
# Epoch 16/16
# 3537/3537 [==============================] - 331s 94ms/step - loss: 1.0080 - acc: 0.7142
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.0634 - acc: 0.6934
# The model accuracy did not improve, patience_i =  2
# -------------------------------------------------------------------------
# Epoch 17 / 20 :
# Training:
# Epoch 17/17
# 3537/3537 [==============================] - 331s 94ms/step - loss: 0.9956 - acc: 0.7117
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.3476 - acc: 0.6640
# The model accuracy did not improve, patience_i =  3
# -------------------------------------------------------------------------
# Epoch 18 / 20 :
# Training:
# Epoch 18/18
# 3537/3537 [==============================] - 331s 94ms/step - loss: 1.0649 - acc: 0.7049
# Validation:
# 416/416 [==============================] - 38s 90ms/step - loss: 1.1306 - acc: 0.6673
# The model accuracy did not improve, patience_i =  4
# -------------------------------------------------------------------------
# Epoch 19 / 20 :
# Training:
# Epoch 19/19
# 3537/3537 [==============================] - 332s 94ms/step - loss: 1.0824 - acc: 0.7035
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.0158 - acc: 0.6919
# The model accuracy did not improve, patience_i =  5
# -------------------------------------------------------------------------
# Epoch 20 / 20 :
# Training:
# Epoch 20/20
# 3537/3537 [==============================] - 330s 93ms/step - loss: 1
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.0822 - acc: 0.6826
# The model accuracy improved from:  0.682153046131134 to:  0.6826041340827942
# -------------------------------------------------------------------------
# Epoch 7 / 20 :
# Training:
# Epoch 7/7
# 3537/3537 [==============================] - 326s 92ms/step - loss: 0.9288 - acc: 0.7349
# Validation:
# 416/416 [==============================] - 37s 89ms/step - loss: 1.0314 - acc: 0.7065
# The model accuracy improved from:  0.6826041340827942 to:  0.7065103054046631
# -------------------------------------------------------------------------
# Epoch 8 / 20 :
# Training:
# Epoch 8/8
# 3537/3537 [==============================] - 326s 92ms/step - loss: 0.9320 - acc: 0.7445
# Validation:
# 416/416 [==============================] - 38s 90ms/step - loss: 1.0970 - acc: 0.7119
# The model accuracy improved from:  0.7065103054046631 to:  0.7119230031967163
# -------------------------------------------------------------------------
# Epoch 9 / 20 :
# Training:
# Epoch 9/9
# 3537/3537 [==============================] - 327s 92ms/step - loss: 0.9943 - acc: 0.7472
# Validation:
# 416/416 [==============================] - 37s 89ms/step - loss: 1.0227 - acc: 0.7176
# The model accuracy improved from:  0.7119230031967163 to:  0.7176364660263062
# -------------------------------------------------------------------------
# Epoch 10 / 20 :
# Training:
# Epoch 10/10
# 3537/3537 [==============================] - 326s 92ms/step - loss: 1.0209 - acc: 0.7506
# Validation:
# 416/416 [==============================] - 38s 90ms/step - loss: 1.0620 - acc: 0.7038
# The model accuracy did not improve, patience_i =  1
# -------------------------------------------------------------------------
# Epoch 11 / 20 :
# Training:
# Epoch 11/11
# 3537/3537 [==============================] - 326s 92ms/step - loss: 0.9289 - acc: 0.7548
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.1859 - acc: 0.6563
# The model accuracy did not improve, patience_i =  2
# -------------------------------------------------------------------------
# Epoch 12 / 20 :
# Training:
# Epoch 12/12
# 3537/3537 [==============================] - 326s 92ms/step - loss: 0.9048 - acc: 0.7554
# Validation:
# 416/416 [==============================] - 38s 90ms/step - loss: 1.1322 - acc: 0.7028
# The model accuracy did not improve, patience_i =  3
# -------------------------------------------------------------------------
# Epoch 13 / 20 :
# Training:
# Epoch 13/13
# 3537/3537 [==============================] - 328s 93ms/step - loss: 0.8744 - acc: 0.7531
# Validation:
# 416/416 [==============================] - 38s 91ms/step - loss: 1.0207 - acc: 0.7100
# The model accuracy did not improve, patience_i =  4
# -------------------------------------------------------------------------
# Epoch 14 / 20 :
# Training:
# Epoch 14/14
# 3537/3537 [==============================] - 328s 93ms/step - loss: 0.9140 - acc: 0.7572
# Validation:
# 416/416 [==============================] - 37s 89ms/step - loss: 1.4855 - acc: 0.7031
# The model accuracy did not improve, patience_i =  5
# -------------------------------------------------------------------------
# Epoch 15 / 20 :
# Training:
# Epoch 15/15
# 3537/3537 [==============================] - 326s 92ms/step - loss: 1.0916 - acc: 0.7559
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.0728 - acc: 0.7218
# The model accuracy improved from:  0.7176364660263062 to:  0.721846342086792
# -------------------------------------------------------------------------
# Epoch 16 / 20 :
# Training:
# Epoch 16/16
# 3537/3537 [==============================] - 326s 92ms/step - loss: 0.9156 - acc: 0.7582
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.1916 - acc: 0.6921
# The model accuracy did not improve, patience_i =  1
# -------------------------------------------------------------------------
# Epoch 17 / 20 :
# Training:
# Epoch 17/17
# 3537/3537 [==============================] - 326s 92ms/step - loss: 0.9297 - acc: 0.7554
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.1697 - acc: 0.6576
# The model accuracy did not improve, patience_i =  2
# -------------------------------------------------------------------------
# Epoch 18 / 20 :
# Training:
# Epoch 18/18
# 3537/3537 [==============================] - 326s 92ms/step - loss: 0.9235 - acc: 0.7558
# Validation:
# 416/416 [==============================] - 37s 89ms/step - loss: 1.0220 - acc: 0.7184
# The model accuracy did not improve, patience_i =  3
# -------------------------------------------------------------------------
# Epoch 19 / 20 :
# Training:
# Epoch 19/19
# 3537/3537 [==============================] - 327s 92ms/step - loss: 0.8676 - acc: 0.7579
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.0332 - acc: 0.7131
# The model accuracy did not improve, patience_i =  4
# -------------------------------------------------------------------------
# Epoch 20 / 20 :
# Training:
# Epoch 20/20
# 3537/3537 [==============================] - 326s 92ms/step - loss: 0.8705 - acc: 0.7606
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.0145 - acc: 0.7040
# The model accuracy did not improve, patience_i =  5
# -------------------------------------------------------------------------
# Testing:
# 209/209 [==============================] - 21s 102ms/step - loss: 1.0072 - acc: 0.6897
# Test Results:  1.0071901082992554 0.6897274851799011
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# -------------------------------------------------------------------------
# Epoch 1 / 20 :
# Training:
# 3537/3537 [==============================] - 328s 93ms/step - loss: 1.6257 - acc: 0.4115
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.3143 - acc: 0.5489
# The model accuracy improved from:  0 to:  0.5489400029182434
# -------------------------------------------------------------------------
# Epoch 2 / 20 :
# Training:
# Epoch 2/2
# 3537/3537 [==============================] - 327s 93ms/step - loss: 1.3176 - acc: 0.5904
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.2422 - acc: 0.6146
# The model accuracy improved from:  0.5489400029182434 to:  0.6146444082260132
# -------------------------------------------------------------------------
# Epoch 3 / 20 :
# Training:
# Epoch 3/3
# 3537/3537 [==============================] - 326s 92ms/step - loss: 1.2583 - acc: 0.6562
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.1156 - acc: 0.6510
# The model accuracy improved from:  0.6146444082260132 to:  0.6510299444198608
# -------------------------------------------------------------------------
# Epoch 4 / 20 :
# Training:
# Epoch 4/4
# 3537/3537 [==============================] - 327s 93ms/step - loss: 1.1409 - acc: 0.6944
# Validation:
# 416/416 [==============================] - 38s 90ms/step - loss: 1.0500 - acc: 0.6736
# The model accuracy improved from:  0.6510299444198608 to:  0.673582911491394
# -------------------------------------------------------------------------
# Epoch 5 / 20 :
# Training:
# Epoch 5/5
# 3537/3537 [==============================] - 327s 92ms/step - loss: 1.2208 - acc: 0.7145
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.0720 - acc: 0.7028
# The model accuracy improved from:  0.673582911491394 to:  0.7027514576911926
# -------------------------------------------------------------------------
# Epoch 6 / 20 :
# Training:
# Epoch 6/6
# 3537/3537 [==============================] - 326s 92ms/step - loss: 1.1085 - acc: 0.7285
# Validation:
# 416/416 [==============================] - 37s 89ms/step - loss: 1.0475 - acc: 0.7015
# The model accuracy did not improve, patience_i =  1
# -------------------------------------------------------------------------
# Epoch 7 / 20 :
# Training:
# Epoch 7/7
# 3537/3537 [==============================] - 327s 92ms/step - loss: 0.9539 - acc: 0.7381
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.0025 - acc: 0.7053
# The model accuracy improved from:  0.7027514576911926 to:  0.7053074836730957
# -------------------------------------------------------------------------
# Epoch 8 / 20 :
# Training:
# Epoch 8/8
# 3537/3537 [==============================] - 326s 92ms/step - loss: 0.9218 - acc: 0.7441
# Validation:
# 416/416 [==============================] - 37s 89ms/step - loss: 1.0738 - acc: 0.6749
# The model accuracy did not improve, patience_i =  1
# -------------------------------------------------------------------------
# Epoch 9 / 20 :
# Training:
# Epoch 9/9
# 3537/3537 [==============================] - 327s 92ms/step - loss: 0.9269 - acc: 0.7502
# Validation:
# 416/416 [==============================] - 38s 91ms/step - loss: 1.0242 - acc: 0.6957
# The model accuracy did not improve, patience_i =  2
# -------------------------------------------------------------------------
# Epoch 10 / 20 :
# Training:
# Epoch 10/10
# 3537/3537 [==============================] - 328s 93ms/step - loss: 0.9266 - acc: 0.7513
# Validation:
# 416/416 [==============================] - 38s 90ms/step - loss: 1.0797 - acc: 0.6760
# The model accuracy did not improve, patience_i =  3
# -------------------------------------------------------------------------
# Epoch 11 / 20 :
# Training:
# Epoch 11/11
# 3537/3537 [==============================] - 324s 92ms/step - loss: 1.2523 - acc: 0.7552
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.2127 - acc: 0.7002
# The model accuracy did not improve, patience_i =  4
# -------------------------------------------------------------------------
# Epoch 12 / 20 :
# Training:
# Epoch 12/12
# 3537/3537 [==============================] - 327s 93ms/step - loss: 0.9212 - acc: 0.7567
# Validation:
# 416/416 [==============================] - 37s 90ms/step - loss: 1.0899 - acc: 0.6847 1s - loss: 1.1136 - a
# The model accuracy did not improve, patience_i =  5
# -------------------------------------------------------------------------
# Epoch 13 / 20 :
# Training:
# Epoch 13/13
#  300/3537 [=>............................] - ETA: 4:46 - loss: 1.0861 - acc: 0.7606- ETA: 4:47 - loss: 1.103
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-4d3af2e65860> in <module>
#      12         input_shape = (i, 128, 128)
#      13         model = BuildModel(input_shape)
# ---> 14         felix_fit_new(model, batch_size, epochs, CPUworkers, [EarlyStop, Checkpoint], AllPaths, "npy", training_history, validation_history, TrainingPatience, test_history, "acc", use_index)
#
# <ipython-input-14-c2974a564c35> in felix_fit_new(model, batch_size, epochs, workers, callbacks, AllPaths, file_type, train_history, val_history, patience, test_history, Monitor, use_index)
#      16         print("Epoch", epoch+1, "/", epochs, ": ")
#      17         print("Training: ")
# ---> 18         train_hist = model.fit(x = train_seq, epochs = epoch+1, workers = workers, initial_epoch = epoch, shuffle=True)
#      19         train_history[0][epoch] = train_hist.history["loss"][0]
#      20         train_history[1][epoch] = train_hist.history["acc"][0]
#
# ~/felix-ML/env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/felix-ML/env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/felix-ML/env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/felix-ML/env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/felix-ML/env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/felix-ML/env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/felix-ML/env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/felix-ML/env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/felix-ML/env/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model.save(NewPath+ModelName)
np.save(NewPath+"/training_history.npy", training_history)
np.save(NewPath+"/validation_history.npy", validation_history)
